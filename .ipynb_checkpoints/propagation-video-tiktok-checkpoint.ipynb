# %% [markdown]
# # Propagation d'une vidéo sur TikTok

# %%
import requests
from bs4 import BeautifulSoup
import random

#Renvoie la liste de 50 musiques populaire actuelle dans l'odre (Spotify)

def musique():

	url = 'https://spotifycharts.com/viral/global/weekly/latest'

	response = requests.get(url)

	if response.ok :
		nom = []
		musique = []
		n = ''
		soup = BeautifulSoup(response.text, 'lxml')
		name = soup.findAll('strong')
	
		for strong in name :
			nom.append(str(strong))

		for i in nom :
			for s in range(8 , len(i) - 9):
				n = n + i[s]

			musique.append(n)
			n = ''

	return musique

#renvoie  la liste des hashtags tiktok populaire 


def hashtag():

	url = 'http://best-hashtags.com/hashtag/tiktok/'

	response = requests.get(url)

	if response.ok :
		nom = []
		hashtag =[]
		lr = []
		n = ''
		soup = BeautifulSoup(response.text, 'lxml')
		name = soup.findAll('p1')
	
		for p1 in name :
			nom.append(str(p1))

		for i in nom :
			for s in i :
				if (s == ' ') :
					lr.append(n)
					n = ''
				n +=s

	for j in range(1,len(lr)):
		hashtag.append(lr[j])


	return hashtag

# Renvoie la listes du top 21 des themes de video populaire sur Tiktok

def themes():

	url = 'https://influencermarketinghub.com/tiktok-video-ideas/'

	response = requests.get(url)

	if response.ok :
		lr = []
		l = []
		th = ''
		theme =[]

		soup = BeautifulSoup(response.text, 'lxml')
		name = soup.findAll('strong')
	
		for strong in name :
			lr.append(str(strong))

		for i in range(2,len(lr)) :
			l.append(lr[i])

		for j in l :
			for s in range(11 , len(j)-9 ) :
				th = th + j[s]

			theme.append(th)
			th = ''

	return theme

# Base video : Assigne de maniere controlé (pas aléatoire) 1 theme , 1 musique , 1 hashtag au tupple (int,str,str,str)


def base_video(nb):

    l1 = themes()
    l2 = musique()
    l3 = hashtag()
    j = 0
    k = 0
    n = 0
    video = []
    i = 1

    while i < nb :
     
      if j >= len(l1):
        j = 0
        i = i +1
      if k >= len(l2) :
        i = i +1
        k = 0
      if n >= len(l3):
        i = i +1
        n = 0
     
      else :
       
        video.append((i , l1[j] , l2[k] , l3[n]))
        i = i + 1
        j = j + 1
        k = k + 1
        n = n + 1

    return (video)

print(base_video(20))
print("\n")

#Base video : Assigne de maniere aleatoire 1 theme , 1 musique , 1 hashtag au tupple (int,str,str,str)

def base_video(nb):

    l1 = themes()
    l2 = musique()
    l3 = hashtag()
    video = []
    i = 1 #Permet d'assigner un identifiant à chaque video

    while i < nb : 
	    video.append((i , random.choice(l1) , random.choice(l2) , random.choice(l3)))
	    i = i + 1

    return (video)

print("\n")
print(base_video(20))
# Out:
# [(1, 'Social Media Challenges', 'YKWIM?', ' #tiktok'), (2, 'Videos Based on Trending Hashtags', 'telepatía', ' #instagram'), (3, 'Dance Videos', 'Preta do Cabelo Cacheado', ' #love'), (4, 'Song Imitations', 'To the Bone', ' #like'), (5, 'Dialogue Reenactments\xa0', "Rollin'", ' #viral'), (6, 'Cute Animal Videos', 'Heartbreak Anniversary', ' #follow'), (7, 'Making Art', 'Iko Iko', ' #memes'), (8, 'Answer Questions by Posing as Song Cover Photo', 'SugarCrash!', ' #explorepage'), (9, 'Satisfying/Calming Videos', 'Astronaut In The Ocean', ' #instagood'), (10, ' Fruit Cutting', 'Friday (feat. Mufasa &amp; Hypeman) - Dopamine Re-Edit', ' #likeforlikes'), (11, ' Voiceovers', 'Track Star', ' #trending'), (12, ' Life in Quarantine', 'Disco Arranhado - Funk Remix', ' #music'), (13, ' Science Experiments', 'Batom de Cereja - Ao Vivo', ' #followforfollowback'), (14, ' Makeover Videos', 'Cloud 9', ' #explore'), (15, ' Collaborations with Influencers', 'Marea (We’ve Lost Dancing)', ' #funny'), (16, ' Tutorials', 'Sometimes (Backwood)', ' #meme'), (17, ' Workout Videos', 'La Llevo Al Cielo', ' #tiktokindonesia'), (18, ' Food/Cooking Videos', 'Fiel', ' #tiktokdance'), (19, ' Freeze-Frame Videos', 'Tokyo', ' #tiktokindia')]
#
#
#
#
# [(1, ' Fruit Cutting', 'To the Bone', ' #tiktokers'), (2, ' Live Videos', 'Chitti (From "Jathi Ratnalu")', ' #likeforlikes'), (3, ' Collaborations with Influencers', 'Slumber Party (feat. Princess Nokia)', ' #likes'), (4, ' Freeze-Frame Videos', 'Rasputin', ' #tiktokindonesia'), (5, 'Satisfying/Calming Videos', 'Tokyo', ' #follow'), (6, ' Live Videos', 'La Llevo Al Cielo', ' #funny'), (7, ' Tutorials', 'Моя голова винтом (My head is spinning like a screw)', ' #fashion'), (8, ' Videos of Your Daily Life', 'Iko Iko', ' #viral'), (9, ' Videos of Your Daily Life', 'Batom de Cereja - Ao Vivo', ' #funny'), (10, 'Song Imitations', 'Uzaklara Savrulalım', ' #explorepage'), (11, 'Dialogue Reenactments\xa0', 'Sometimes (Backwood)', ' #follow'), (12, ' Live Videos', 'Heartbreak Anniversary', ' #youtube'), (13, ' Collaborations with Influencers', 'La Llevo Al Cielo', ' #photography'), (14, ' Collaborations with Influencers', 'Saturno', ' #follow'), (15, ' Tutorials', 'Iko Iko', ' #likeforlikes'), (16, ' Freeze-Frame Videos', 'La Llevo Al Cielo', ' #k'), (17, ' Life in Quarantine', '501', ' #instagram'), (18, ' Food/Cooking Videos', 'Amarelo, azul e branco', ' #tiktokdance'), (19, 'Song Imitations', 'Cloud 9', ' #fashion')]

# %% [markdown]
# ## base_utilisateur
#
# La fonction `base_utilisateur` renvoie un liste de tuples du format `identifiant, musique_favorie, hashtags_favoris, themes_favoris`. Sa sortie sera utilisée pour la fonction `interaction`.

# %%
def base_utilisateur(nb , long): #nb = nombre d'utilisateur , long = nb de donées dans chaque liste

	# renvoie une liste de Tuple de type (identifiant , liste musique favoris , liste hashtag favoris , liste theme favoris)
	base = []
	lh = [] #liste hashtag favoris
	lm = []	#liste musique favoris 
	lt = [] #liste theme favoris
	l1 = musique()
	l2 = hashtag()
	l3 = themes()
	j =  0
	i = 1

	while i < nb :
		while j < long :
			lm.append(random.choice(l1))
			lh.append(random.choice(l2))
			lt.append(random.choice(l3))
			j = j + 1
		
		base.append((i , lm , lh , lt))
		i = i + 1
		j = 0
		lm = []
		lh = []
		lt =[]

	return base

print("\n")
print(base_utilisateur(20,5))
# Out:
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# --------------------------------------------------------------------------------------------
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# --------------------------------------------------------------------------------------------
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# --------------------------------------------------------------------------------------------
#
#
#
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# --------------------------------------------------------------------------------------------
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# --------------------------------------------------------------------------------------------
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# --------------------------------------------------------------------------------------------
#
#
#
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# --------------------------------------------------------------------------------------------
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# --------------------------------------------------------------------------------------------
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# --------------------------------------------------------------------------------------------
#
#
#
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# --------------------------------------------------------------------------------------------
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# --------------------------------------------------------------------------------------------
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# [(15, 'Videos Based on Trending Hashtags', 'Arcade', ' #tiktokdance')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# --------------------------------------------------------------------------------------------
#
#
#
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(4, ' Life in Quarantine', 'Lut Gaye', ' #meme')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(10, 'Videos Based on Trending Hashtags', 'Iko Iko', ' #bhfyp')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# --------------------------------------------------------------------------------------------
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(16, ' Tutorials', 'Amarelo, azul e branco', ' #cute')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(11, ' Freeze-Frame Videos', 'Boku no Sensou', ' #art')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(13, ' Science Experiments', 'Wellerman - Sea Shanty', ' #love')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(8, 'Answer Questions by Posing as Song Cover Photo', 'Weak', ' #likeforlikes')]
# --------------------------------------------------------------------------------------------
# [(18, ' Workout Videos', 'Ella No Es Tuya - Remix', ' #meme')]
# [(5, 'Dance Videos', 'Disco Arranhado - Funk Remix', ' #trending')]
# [(19, 'Answer Questions by Posing as Song Cover Photo', 'Amarelo, azul e branco', ' #k')]
# [(1, ' Collaborations with Influencers', 'Ella No Es Tuya - Remix', ' #music')]
# [(6, 'Social Media Challenges', 'Cloud 9', ' #tiktokindia')]
# [(2, 'Dialogue Reenactments\xa0', 'Disco Arranhado - Funk Remix', ' #tiktokers')]
# [(7, ' Videos of Your Daily Life', 'CHICKEN TENDIES', ' #funny')]
# [(9, ' Science Experiments', '501', ' #like')]
# [(14, ' Food/Cooking Videos', 'Heartbreak Anniversary', ' #tiktokindia')]
# [(17, ' Science Experiments', "Rollin'", ' #meme')]
# [(12, 'Satisfying/Calming Videos', 'Ordentlich', ' #fashion')]
# [(3, ' Creative', 'Amarelo, azul e branco', ' #k')]
# --------------------------------------------------------------------------------------------
